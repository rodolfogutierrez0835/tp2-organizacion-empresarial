# %% [markdown]
# # TP2 - Gestión Colaborativa y Organización Empresarial
#
# ## Integrantes
# - Rodolfo Gutierrez
# - Lucía Gutierrez
#
# ## Objetivo
# Analizar un dataset de ventas utilizando herramientas colaborativas como GitHub, Jira y Google Colab.

# %%
# !git clone https://github.com/rodolfogutierrez0835/tp2-organizacion-empresarial.git
# Out:
# Cloning into 'tp2-organizacion-empresarial'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 62 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 20.91 KiB | 5.23 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# %cd tp2-organizacion-empresarial
# Out:
# /content/tp2-organizacion-empresarial

# %%
# !ls
# Out:
# datos  docs  README.md	resultados  scripts

# %%
# %cd scripts
# Out:
# /content/tp2-organizacion-empresarial/scripts

# %%
# !ls
# Out:
# analisis_ventas.py  README.md

# %%
# !python analisis_ventas.py
# Out:
# Ventas totales: 561000
# Producto más vendido: Mouse
# Ventas por mes:
# mes
# 2026-01    174000
# 2026-02     92000
# 2026-03    295000
# Freq: M, Name: total, dtype: int64

# %%
# %cd /content/tp2-organizacion-empresarial
# !ls resultados
# Out:
# /content/tp2-organizacion-empresarial
# grafico_ventas.png  README.md

# %%
from IPython.display import Image
Image("resultados/grafico_ventas.png")
